# %% [markdown]
# ## how to use psutil
# ### install
# ```
# pip install psutil
# ```
# ### start
# ```
# import psutil
# ```

# %%
import psutil

# %%
psutil.test()
# Out:
# USER         PID %MEM     VSZ     RSS TTY           START    TIME  COMMAND
# SYSTEM         0    ?       ?      24 ?             08:57   53:04  System Idle Process
# SYSTEM         4    ?     192    2680 ?             08:57   04:08  System
# LOCAL SERV   156  0.2   25588   21764 ?             08:57   00:03  svchost.exe
# SYSTEM       360    ?     564    1240 ?             08:57   00:00  smss.exe
# SYSTEM       376  0.2    9472   19672 ?             08:57   00:00  svchost.exe
# SYSTEM       584  0.1    2524    6328 ?             08:57   00:00  csrss.exe
# LOCAL SERV   592  0.2    9556   25376 ?             08:57   00:01  svchost.exe
# SYSTEM       624  0.3   21736   35916 ?             08:57   00:05  svchost.exe
# Administra   656  0.3   28212   33940 ?             09:02   00:00  chrome.exe
# SYSTEM       660    ?    1912    5508 ?             08:57   00:00  wininit.exe
# SYSTEM       668  1.2    4284  144544 ?             08:57   00:55  csrss.exe
# ...
